# %% [markdown]
# ### Обрабатываем и обучаемся на train

# %%
import pandas as pd
my_csv = pd.read_csv('C://Put_txt/ruscorpora_parsed.txt', sep='/')

# %%
my_csv.head()
# Out:
#   Словоформа        лемма            Морфологический разбор
# 0   Якутское     якутский                   A=n,sg,nom,plen
# 1  отделение    отделение                   S,n,inan=sg,nom
# 2     Единой       единый                   A=f,sg,gen,plen
# 3     России       Россия                   S,f,inan=sg,gen
# 4  планирует  планировать  V,ipf,tran=sg,act,praes,3p,indic

# %%
import re
POS = []
for my_data in my_csv['Морфологический разбор']:
    res = re.search('[A-Z]*(-[A-Z]*)?', my_data)
    POS.append(res.group(0))
my_csv['POS'] = POS

# %%
my_csv.head()
# Out:
#   Словоформа        лемма            Морфологический разбор POS
# 0   Якутское     якутский                   A=n,sg,nom,plen   A
# 1  отделение    отделение                   S,n,inan=sg,nom   S
# 2     Единой       единый                   A=f,sg,gen,plen   A
# 3     России       Россия                   S,f,inan=sg,gen   S
# 4  планирует  планировать  V,ipf,tran=sg,act,praes,3p,indic   V

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()
real_1 = pd.Series(label_encoder.fit_transform(my_csv['POS'].astype(str)))
dict1 = dict(enumerate(label_encoder.classes_))

# %% [markdown]
# ### Кодируем train data

# %%
categorical_columns = my_csv.columns[my_csv.dtypes == 'object'].union(['POS'])
for column in categorical_columns:
    my_csv[column] = label_encoder.fit_transform(my_csv[column].astype(str))
my_csv.head()
# Out:
#    Словоформа  лемма  Морфологический разбор  POS
# 0       29302  50918                     523    1
# 1       82438  32539                    1328   17
# 2       11064  19704                     453    1
# 3       22805   9577                     941   17
# 4       87665  34594                    2404   19

# %%
y = my_csv['POS']
my_csv = my_csv.drop('POS', 1)

# %%
my_csv = my_csv.drop('Морфологический разбор', 1)
my_csv.head()
# Out:
#    Словоформа  лемма
# 0       29302  50918
# 1       82438  32539
# 2       11064  19704
# 3       22805   9577
# 4       87665  34594

# %%
onehot_encoder = OneHotEncoder(sparse=True)
X = onehot_encoder.fit_transform(my_csv)

# %% [markdown]
# ### Мы обучаемся на train методом LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(n_jobs=-1, verbose=5)
clf = clf.fit(X, y)
# Out:
# c:\users\maria tsareva\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [LibLinear]

# %% [markdown]
# ### Открываем текст test и золотой стандарт, проводим препроцессинг
#
# Мы токенизируем текст и предстказываем части речи токенов по средствам обученного алгоритма. После этого сравниваем с золотым стандартом. Но что-то пошло не так, потому что золотой стандарт не совпадает с текстом. Поэтому, далее мы решили применить алгоритм к леммам из золотого стандарта, расставить тэги и сравить с резульататми золотого стандарта.

# %%
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from pymorphy2 import MorphAnalyzer
import matplotlib.pyplot as plt
# %matplotlib inline 

morph = MorphAnalyzer()

with open ('C://Put_txt/ruscorpora_parsed.txt', 'r', encoding = 'Windows-1251') as f:
    text = f.read()

def first_normalize(text):
    lemmas = []
    text = text.lower()
    text = re.sub('!|\#|\$|%|\&|\(|\)|\*|\+|,|-|\.|\/|\:|;|<|=|>|\?|\@|\[|\]|^|_|`|\{|\}|~|«|«|»|"|…', '', text)
    text = re.sub('(http://|https://|www.)[a-zA-z0-9]*? ', '', text)
    text = re.sub('[A-Za-z0-9]+', '', text)
    text = re.sub('\s+|\n|\t', ' ', text)
    tokens = wordpunct_tokenize(text)
    for el in tokens:
        lemmas.append(morph.parse(el)[0].normal_form)
    
    clean_lemmas = [lemma for lemma in lemmas]
    
    return tokens, clean_lemmas

tokens, clean_lemmas = first_normalize(text)

new_data = pd.DataFrame()
new_data['Словоформа'] = tokens
new_data['Лемма'] = clean_lemmas

# %%
real_11 = pd.Series(label_encoder.fit_transform(new_data['Словоформа'].astype(str)))
categorical_columns = new_data.columns[new_data.dtypes == 'object'].union(['Словоформа'])
for column in categorical_columns:
    new_data[column] = label_encoder.fit_transform(new_data[column].astype(str))
new_data.head()
# Out:
#    Словоформа  Лемма
# 0        1504   1243
# 1         289    231
# 2        1489   1227
# 3         794    645
# 4        1244   1025

# %%
X1 = onehot_encoder.transform(new_data)
X1
# Out:
# <2322x184026 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4644 stored elements in Compressed Sparse Row format>

# %%
Y_pred = clf.predict(X1)

# %%
Y_pred
# Out:
# array([11, 17, 17, ..., 17, 17, 17])

# %%
with open ('C://Put_txt/GoldStandard.txt', 'r', encoding='utf-8') as f:
    gold_text = f.read()

# %%
gold_text = re.sub('!|\#|\$|%|\&|\(|\)|\*|\+|,|-|\.|\/|\:|;|<|=|>|\?|\@|\[|\]|^|_|`|\{|\}|~|«|«|»|"|…', '', gold_text)
gold_text = re.sub('[a-z0-9]+', '', gold_text)
gold_text = re.sub('\n+', '\n', gold_text)

# %%
with open ('C://Put_txt/gold.txt', 'w', encoding = 'utf-8') as f:
    f.write(gold_text)

# %%
new_csv = pd.read_csv('C://Put_txt/gold1.txt', encoding = 'Windows-1251', sep=' ')
new_csv = new_csv.drop('Unnamed: 3', 1)
new_csv = new_csv.dropna()
new_csv.columns = ['Word', 'Lemma', 'POS']

# %%
new_csv.head()
# Out:
#            Word         Lemma POS
# 0        Цветки        цветок   S
# 1  дикорастущих  дикорастущий   A
# 2          форм         форма   S
# 3  обыкновенной  обыкновенный   A
# 4        сирени        сирень   S

# %% [markdown]
# ## А ТЕПЕРЬ НОРМАЛЬНО

# %%
real_11 = pd.Series(label_encoder.fit_transform(new_csv['POS'].astype(str)))
dict2 = dict(enumerate(label_encoder.classes_))
categorical_columns = new_csv.columns[new_csv.dtypes == 'object'].union(['POS'])
for column in categorical_columns:
    new_csv[column] = label_encoder.fit_transform(new_csv[column].astype(str))

new_csv.head()
# Out:
#    Word  Lemma  POS
# 0   298   1379    7
# 1   577    356    0
# 2  1739   1364    7
# 3  1042    761    0
# 4  1504   1159    7

# %%
y_test = new_csv['POS']
new_csv = new_csv.drop('POS', 1)

# %%
X2 = onehot_encoder.transform(new_csv)
X2
# Out:
# <2661x184026 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5322 stored elements in Compressed Sparse Row format>

# %%
Y_pred = clf.predict(X2)

# %%
Y_pred
# Out:
# array([17, 11, 17, ..., 17, 17, 17], dtype=int32)

# %%
Y_pr = Y_pred.tolist()
print(len(Y_pr))
Y_ts = y_test.tolist()
print(len(Y_ts))
# Out:
# 2661
# 2661

# %%
Y_pr_n = []
for y in Y_pr:
    for key, value in dict1.items():
        if y == key:
            y = dict1[key]
            Y_pr_n.append(y)
Y_pr_n
# Out:
# ['S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'NONLEX',
#  'NONLEX',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NONLEX',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NONLEX',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NONLEX',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'ANUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NONLEX',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'NUM',
#  'NUM',
#  'NUM',
#  'S',
#  'S',
#  'S',
#  ...]

# %%
Y_ts_n = []
for y in Y_ts:
    for key, value in dict2.items():
        if y == key:
            y = dict2[key]
            Y_ts_n.append(y)
Y_ts_n
# Out:
# ['S',
#  'A',
#  'S',
#  'A',
#  'S',
#  'A',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'S',
#  'V',
#  'A',
#  'PR',
#  'S',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'V',
#  'A',
#  'S',
#  'A',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'ADV',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'V',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'ADV',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'CONJ',
#  'V',
#  'A',
#  'S',
#  'ADV',
#  'S',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'PR',
#  'A',
#  'A',
#  'S',
#  'A',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'ADV',
#  'PR',
#  'A',
#  'A',
#  'ADV',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'ADV',
#  'S',
#  'A',
#  'CONJ',
#  'A',
#  'S',
#  'PR',
#  'APRO',
#  'S',
#  'SPRO',
#  'ADV',
#  'APRO',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'ADV',
#  'SPRO',
#  'V',
#  'SPRO',
#  'PR',
#  'S',
#  'S',
#  'ADV',
#  'ADV',
#  'SPRO',
#  'V',
#  'A',
#  'CONJ',
#  'A',
#  'S',
#  'S',
#  'V',
#  'V',
#  'S',
#  'A',
#  'S',
#  'CONJ',
#  'V',
#  'A',
#  'S',
#  'A',
#  'S',
#  'S',
#  'ADV',
#  'CONJ',
#  'ADV',
#  'V',
#  'PR',
#  'V',
#  'S',
#  'ADV',
#  'V',
#  'ADV',
#  'A',
#  'S',
#  'SPRO',
#  'V',
#  'PR',
#  'S',
#  'ADV',
#  'CONJ',
#  'A',
#  'V',
#  'V',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'APRO',
#  'S',
#  'PR',
#  'SPRO',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'APRO',
#  'A',
#  'S',
#  'ADV',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'A',
#  'S',
#  'APRO',
#  'S',
#  'ADV',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'V',
#  'A',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'SPRO',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'APRO',
#  'S',
#  'A',
#  'S',
#  'ADV',
#  'S',
#  'V',
#  'ADV',
#  'ADV',
#  'ADV',
#  'APRO',
#  'SPRO',
#  'V',
#  'PR',
#  'S',
#  'APRO',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'A',
#  'S',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'S',
#  'S',
#  'V',
#  'V',
#  'S',
#  'CONJ',
#  'S',
#  'V',
#  'V',
#  'S',
#  'NUM',
#  'V',
#  'PR',
#  'A',
#  'CONJ',
#  'A',
#  'A',
#  'S',
#  'CONJ',
#  'ADV',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'APRO',
#  'S',
#  'V',
#  'A',
#  'S',
#  'APRO',
#  'V',
#  'ADV',
#  'A',
#  'S',
#  'S',
#  'SPRO',
#  'ADV',
#  'ADV',
#  'A',
#  'PR',
#  'ANUM',
#  'S',
#  'S',
#  'V',
#  'A',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'V',
#  'S',
#  'A',
#  'S',
#  'S',
#  'CONJ',
#  'A',
#  'S',
#  'V',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'CONJ',
#  'S',
#  'ADV',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'V',
#  'V',
#  'S',
#  'ADV',
#  'A',
#  'S',
#  'CONJ',
#  'S',
#  'S',
#  'ANUM',
#  'S',
#  'APRO',
#  'S',
#  'S',
#  'A',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'A',
#  'S',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'V',
#  'S',
#  'PR',
#  'APRO',
#  'S',
#  'A',
#  'S',
#  'S',
#  'ADV',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'SPRO',
#  'V',
#  'PR',
#  'SPRO',
#  'CONJ',
#  'S',
#  'CONJ',
#  'PR',
#  'A',
#  'S',
#  'ADV',
#  'V',
#  'ADV',
#  'ANUM',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'PR',
#  'SPRO',
#  'ADV',
#  'V',
#  'APRO',
#  'A',
#  'S',
#  'A',
#  'S',
#  'S',
#  'V',
#  'A',
#  'A',
#  'S',
#  'APRO',
#  'V',
#  'S',
#  'S',
#  'V',
#  'ADV',
#  'S',
#  'S',
#  'V',
#  'APRO',
#  'S',
#  'PR',
#  'S',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'APRO',
#  'S',
#  'V',
#  'A',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'A',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'SPRO',
#  'ADV',
#  'V',
#  'SPRO',
#  'SPRO',
#  'APRO',
#  'S',
#  'ADV',
#  'S',
#  'A',
#  'PR',
#  'S',
#  'SPRO',
#  'V',
#  'CONJ',
#  'S',
#  'V',
#  'A',
#  'S',
#  'S',
#  'V',
#  'A',
#  'CONJ',
#  'A',
#  'A',
#  'S',
#  'CONJ',
#  'S',
#  'S',
#  'A',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'V',
#  'PR',
#  'APRO',
#  'S',
#  'PR',
#  'APRO',
#  'S',
#  'S',
#  'PR',
#  'NUM',
#  'ADV',
#  'ADV',
#  'APRO',
#  'S',
#  'ADV',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'ADV',
#  'SPRO',
#  'ADV',
#  'V',
#  'SPRO',
#  'PR',
#  'S',
#  'ADV',
#  'ADV',
#  'V',
#  'ADV',
#  'V',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'V',
#  'V',
#  'V',
#  'V',
#  'ADV',
#  'V',
#  'ADV',
#  'ADV',
#  'ADV',
#  'S',
#  'V',
#  'ADV',
#  'CONJ',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'APRO',
#  'S',
#  'APRO',
#  'A',
#  'S',
#  'V',
#  'ADV',
#  'PR',
#  'S',
#  'APRO',
#  'A',
#  'S',
#  'SPRO',
#  'V',
#  'V',
#  'PR',
#  'APRO',
#  'S',
#  'CONJ',
#  'V',
#  'SPRO',
#  'ADV',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'V',
#  'S',
#  'CONJ',
#  'SPRO',
#  'ADV',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'V',
#  'ADV',
#  'V',
#  'A',
#  'ADV',
#  'V',
#  'S',
#  'SPRO',
#  'V',
#  'ADV',
#  'V',
#  'SPRO',
#  'S',
#  'CONJ',
#  'ADV',
#  'V',
#  'CONJ',
#  'SPRO',
#  'V',
#  'PR',
#  'APRO',
#  'S',
#  'S',
#  'S',
#  'CONJ',
#  'ADV',
#  'V',
#  'CONJ',
#  'SPRO',
#  'V',
#  'SPRO',
#  'V',
#  'SPRO',
#  'V',
#  'S',
#  'ADV',
#  'PR',
#  'S',
#  'V',
#  'S',
#  'CONJ',
#  'SPRO',
#  'V',
#  'SPRO',
#  'CONJ',
#  'A',
#  'S',
#  'V',
#  'CONJ',
#  'PR',
#  'APRO',
#  'S',
#  'SPRO',
#  'ADV',
#  'ADV',
#  'V',
#  'S',
#  'S',
#  'CONJ',
#  'APRO',
#  'S',
#  'APRO',
#  'APRO',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'CONJ',
#  'ADV',
#  'V',
#  'S',
#  'PR',
#  'APRO',
#  'ADV',
#  'V',
#  'V',
#  'S',
#  'V',
#  'CONJ',
#  'V',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'V',
#  'SPRO',
#  'S',
#  'APRO',
#  'ADV',
#  'V',
#  'SPRO',
#  'PR',
#  'SPRO',
#  'SPRO',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'V',
#  'V',
#  'APRO',
#  'S',
#  'A',
#  'S',
#  'S',
#  'CONJ',
#  'A',
#  'S',
#  'PR',
#  'V',
#  'S',
#  'V',
#  'S',
#  'S',
#  'V',
#  'PR',
#  'APRO',
#  'PR',
#  'APRO',
#  'S',
#  'CONJ',
#  'ADV',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'A',
#  'A',
#  'S',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'PR',
#  'APRO',
#  'S',
#  'A',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'V',
#  'CONJ',
#  'ADV',
#  'V',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'V',
#  'SPRO',
#  'S',
#  'S',
#  'V',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'A',
#  'S',
#  'APRO',
#  'V',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'APRO',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'APRO',
#  'S',
#  'SPRO',
#  'V',
#  'V',
#  'PR',
#  'S',
#  'PR',
#  'S',
#  'PR',
#  'V',
#  'S',
#  'A',
#  'S',
#  'CONJ',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'A',
#  'A',
#  'S',
#  'ADV',
#  'V',
#  'APRO',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'A',
#  'A',
#  'S',
#  'S',
#  'V',
#  'S',
#  'CONJ',
#  'CONJ',
#  'S',
#  'PR',
#  'A',
#  'CONJ',
#  'A',
#  'S',
#  'CONJ',
#  'V',
#  'PR',
#  'APRO',
#  'S',
#  'V',
#  'V',
#  'ADV',
#  'SPRO',
#  'CONJ',
#  'PR',
#  'APRO',
#  'S',
#  'V',
#  'S',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'A',
#  'S',
#  'V',
#  'V',
#  'V',
#  'CONJ',
#  'APRO',
#  'S',
#  'V',
#  'V',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'A',
#  'S',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'A',
#  'S',
#  'V',
#  'A',
#  'CONJ',
#  'ADV',
#  'V',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'V',
#  'A',
#  'S',
#  'V',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'A',
#  'S',
#  'PR',
#  'V',
#  'S',
#  'V',
#  'V',
#  'CONJ',
#  'A',
#  'S',
#  'A',
#  'S',
#  'ADV',
#  'PR',
#  'S',
#  'S',
#  'A',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'A',
#  'S',
#  'CONJ',
#  'S',
#  'S',
#  'S',
#  'A',
#  'S',
#  'A',
#  'S',
#  'V',
#  'ADV',
#  'V',
#  'A',
#  'S',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'A',
#  'S',
#  'ADV',
#  'PR',
#  'ADV',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'V',
#  'A',
#  'S',
#  'PR',
#  'A',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'V',
#  'S',
#  'PR',
#  'A',
#  'A',
#  'S',
#  'CONJ',
#  'A',
#  'S',
#  'S',
#  'S',
#  'CONJ',
#  'S',
#  'S',
#  'PR',
#  'A',
#  'A',
#  'S',
#  'A',
#  'CONJ',
#  'A',
#  'S',
#  'S',
#  'A',
#  'S',
#  'PR',
#  'S',
#  'S',
#  'S',
#  'S',
#  'PR',
#  'S',
#  'A',
#  'S',
#  ...]

# %%
Y_ts = []
for y in Y_ts_n:
    for key, value in dict1.items():
        if y == dict1[key]:
            y = key
        if (y == 'APRO') or (y == 'SPRO'):
            y = 20
    Y_ts.append(int(y))
Y_ts
# Out:
# [17,
#  1,
#  17,
#  1,
#  17,
#  1,
#  19,
#  1,
#  17,
#  14,
#  17,
#  14,
#  17,
#  1,
#  17,
#  14,
#  17,
#  14,
#  17,
#  17,
#  17,
#  17,
#  19,
#  1,
#  14,
#  17,
#  17,
#  1,
#  17,
#  14,
#  17,
#  17,
#  14,
#  17,
#  17,
#  7,
#  17,
#  19,
#  1,
#  17,
#  1,
#  17,
#  17,
#  4,
#  19,
#  14,
#  1,
#  17,
#  14,
#  4,
#  1,
#  17,
#  14,
#  1,
#  17,
#  14,
#  1,
#  17,
#  14,
#  1,
#  17,
#  19,
#  17,
#  17,
#  4,
#  19,
#  4,
#  17,
#  17,
#  14,
#  17,
#  1,
#  17,
#  7,
#  19,
#  1,
#  17,
#  4,
#  17,
#  17,
#  17,
#  4,
#  19,
#  17,
#  1,
#  17,
#  14,
#  17,
#  17,
#  14,
#  17,
#  17,
#  14,
#  1,
#  1,
#  17,
#  1,
#  17,
#  19,
#  14,
#  17,
#  17,
#  7,
#  19,
#  14,
#  17,
#  14,
#  17,
#  17,
#  17,
#  4,
#  14,
#  1,
#  1,
#  4,
#  17,
#  19,
#  14,
#  17,
#  14,
#  17,
#  17,
#  17,
#  4,
#  17,
#  1,
#  7,
#  1,
#  17,
#  14,
#  20,
#  17,
#  20,
#  4,
#  20,
#  17,
#  19,
#  14,
#  17,
#  17,
#  4,
#  20,
#  19,
#  20,
#  14,
#  17,
#  17,
#  4,
#  4,
#  20,
#  19,
#  1,
#  7,
#  1,
#  17,
#  17,
#  19,
#  19,
#  17,
#  1,
#  17,
#  7,
#  19,
#  1,
#  17,
#  1,
#  17,
#  17,
#  4,
#  7,
#  4,
#  19,
#  14,
#  19,
#  17,
#  4,
#  19,
#  4,
#  1,
#  17,
#  20,
#  19,
#  14,
#  17,
#  4,
#  7,
#  1,
#  19,
#  19,
#  17,
#  17,
#  14,
#  17,
#  20,
#  17,
#  14,
#  20,
#  19,
#  14,
#  17,
#  14,
#  17,
#  14,
#  1,
#  17,
#  17,
#  20,
#  1,
#  17,
#  4,
#  19,
#  14,
#  17,
#  14,
#  17,
#  1,
#  1,
#  17,
#  20,
#  17,
#  4,
#  19,
#  1,
#  17,
#  14,
#  17,
#  1,
#  17,
#  14,
#  1,
#  17,
#  19,
#  1,
#  17,
#  17,
#  7,
#  17,
#  14,
#  17,
#  17,
#  17,
#  14,
#  20,
#  17,
#  14,
#  17,
#  17,
#  4,
#  19,
#  14,
#  17,
#  14,
#  20,
#  17,
#  1,
#  17,
#  4,
#  17,
#  19,
#  4,
#  4,
#  4,
#  20,
#  20,
#  19,
#  14,
#  17,
#  20,
#  17,
#  14,
#  17,
#  17,
#  6,
#  17,
#  1,
#  17,
#  17,
#  19,
#  14,
#  17,
#  14,
#  17,
#  1,
#  17,
#  17,
#  17,
#  19,
#  19,
#  17,
#  7,
#  17,
#  19,
#  19,
#  17,
#  11,
#  19,
#  14,
#  1,
#  7,
#  1,
#  1,
#  17,
#  7,
#  4,
#  19,
#  14,
#  1,
#  17,
#  20,
#  17,
#  19,
#  1,
#  17,
#  20,
#  19,
#  4,
#  1,
#  17,
#  17,
#  20,
#  4,
#  4,
#  1,
#  14,
#  6,
#  17,
#  17,
#  19,
#  1,
#  17,
#  17,
#  14,
#  17,
#  14,
#  19,
#  17,
#  1,
#  17,
#  17,
#  7,
#  1,
#  17,
#  19,
#  19,
#  14,
#  1,
#  17,
#  17,
#  14,
#  1,
#  17,
#  7,
#  17,
#  4,
#  17,
#  17,
#  7,
#  17,
#  19,
#  19,
#  17,
#  4,
#  1,
#  17,
#  7,
#  17,
#  17,
#  6,
#  17,
#  20,
#  17,
#  17,
#  1,
#  19,
#  14,
#  1,
#  17,
#  14,
#  1,
#  17,
#  17,
#  17,
#  17,
#  14,
#  1,
#  17,
#  14,
#  17,
#  1,
#  1,
#  17,
#  17,
#  17,
#  4,
#  19,
#  19,
#  17,
#  14,
#  20,
#  17,
#  1,
#  17,
#  17,
#  4,
#  19,
#  14,
#  17,
#  14,
#  20,
#  19,
#  14,
#  20,
#  7,
#  17,
#  7,
#  14,
#  1,
#  17,
#  4,
#  19,
#  4,
#  6,
#  17,
#  1,
#  17,
#  14,
#  14,
#  20,
#  4,
#  19,
#  20,
#  1,
#  17,
#  1,
#  17,
#  17,
#  19,
#  1,
#  1,
#  17,
#  20,
#  19,
#  17,
#  17,
#  19,
#  4,
#  17,
#  17,
#  19,
#  20,
#  17,
#  14,
#  17,
#  19,
#  14,
#  1,
#  17,
#  20,
#  17,
#  19,
#  1,
#  17,
#  17,
#  7,
#  17,
#  1,
#  17,
#  17,
#  7,
#  17,
#  20,
#  4,
#  19,
#  20,
#  20,
#  20,
#  17,
#  4,
#  17,
#  1,
#  14,
#  17,
#  20,
#  19,
#  7,
#  17,
#  19,
#  1,
#  17,
#  17,
#  19,
#  1,
#  7,
#  1,
#  1,
#  17,
#  7,
#  17,
#  17,
#  1,
#  1,
#  17,
#  14,
#  17,
#  1,
#  17,
#  19,
#  14,
#  20,
#  17,
#  14,
#  20,
#  17,
#  17,
#  14,
#  11,
#  4,
#  4,
#  20,
#  17,
#  4,
#  19,
#  14,
#  1,
#  17,
#  4,
#  20,
#  4,
#  19,
#  20,
#  14,
#  17,
#  4,
#  4,
#  19,
#  4,
#  19,
#  19,
#  14,
#  17,
#  17,
#  17,
#  19,
#  19,
#  19,
#  19,
#  4,
#  19,
#  4,
#  4,
#  4,
#  17,
#  19,
#  4,
#  7,
#  17,
#  19,
#  14,
#  17,
#  20,
#  17,
#  20,
#  1,
#  17,
#  19,
#  4,
#  14,
#  17,
#  20,
#  1,
#  17,
#  20,
#  19,
#  19,
#  14,
#  20,
#  17,
#  7,
#  19,
#  20,
#  4,
#  19,
#  14,
#  1,
#  17,
#  19,
#  17,
#  7,
#  20,
#  4,
#  19,
#  14,
#  17,
#  17,
#  19,
#  4,
#  19,
#  1,
#  4,
#  19,
#  17,
#  20,
#  19,
#  4,
#  19,
#  20,
#  17,
#  7,
#  4,
#  19,
#  7,
#  20,
#  19,
#  14,
#  20,
#  17,
#  17,
#  17,
#  7,
#  4,
#  19,
#  7,
#  20,
#  19,
#  20,
#  19,
#  20,
#  19,
#  17,
#  4,
#  14,
#  17,
#  19,
#  17,
#  7,
#  20,
#  19,
#  20,
#  7,
#  1,
#  17,
#  19,
#  7,
#  14,
#  20,
#  17,
#  20,
#  4,
#  4,
#  19,
#  17,
#  17,
#  7,
#  20,
#  17,
#  20,
#  20,
#  17,
#  19,
#  14,
#  17,
#  7,
#  4,
#  19,
#  17,
#  14,
#  20,
#  4,
#  19,
#  19,
#  17,
#  19,
#  7,
#  19,
#  14,
#  17,
#  1,
#  17,
#  19,
#  20,
#  17,
#  20,
#  4,
#  19,
#  20,
#  14,
#  20,
#  20,
#  19,
#  14,
#  17,
#  17,
#  19,
#  19,
#  20,
#  17,
#  1,
#  17,
#  17,
#  7,
#  1,
#  17,
#  14,
#  19,
#  17,
#  19,
#  17,
#  17,
#  19,
#  14,
#  20,
#  14,
#  20,
#  17,
#  7,
#  4,
#  19,
#  14,
#  17,
#  14,
#  1,
#  17,
#  17,
#  1,
#  1,
#  17,
#  17,
#  14,
#  1,
#  17,
#  14,
#  17,
#  17,
#  14,
#  20,
#  17,
#  1,
#  17,
#  19,
#  14,
#  17,
#  17,
#  19,
#  14,
#  17,
#  14,
#  17,
#  1,
#  17,
#  19,
#  7,
#  4,
#  19,
#  17,
#  17,
#  17,
#  14,
#  17,
#  17,
#  7,
#  17,
#  19,
#  20,
#  17,
#  17,
#  19,
#  17,
#  17,
#  17,
#  14,
#  17,
#  14,
#  17,
#  17,
#  7,
#  1,
#  17,
#  20,
#  19,
#  19,
#  14,
#  17,
#  14,
#  17,
#  17,
#  20,
#  17,
#  19,
#  14,
#  17,
#  20,
#  17,
#  20,
#  19,
#  19,
#  14,
#  17,
#  14,
#  17,
#  14,
#  19,
#  17,
#  1,
#  17,
#  7,
#  19,
#  14,
#  1,
#  17,
#  1,
#  1,
#  17,
#  4,
#  19,
#  20,
#  1,
#  17,
#  14,
#  17,
#  17,
#  7,
#  17,
#  1,
#  1,
#  17,
#  17,
#  19,
#  17,
#  7,
#  7,
#  17,
#  14,
#  1,
#  7,
#  1,
#  17,
#  7,
#  19,
#  14,
#  20,
#  17,
#  19,
#  19,
#  4,
#  20,
#  7,
#  14,
#  20,
#  17,
#  19,
#  17,
#  17,
#  1,
#  17,
#  14,
#  17,
#  17,
#  1,
#  17,
#  19,
#  19,
#  19,
#  7,
#  20,
#  17,
#  19,
#  19,
#  19,
#  1,
#  17,
#  14,
#  17,
#  17,
#  1,
#  17,
#  17,
#  19,
#  14,
#  17,
#  1,
#  17,
#  19,
#  1,
#  7,
#  4,
#  19,
#  14,
#  1,
#  17,
#  17,
#  19,
#  1,
#  17,
#  19,
#  14,
#  17,
#  17,
#  7,
#  1,
#  17,
#  14,
#  19,
#  17,
#  19,
#  19,
#  7,
#  1,
#  17,
#  1,
#  17,
#  4,
#  14,
#  17,
#  17,
#  1,
#  17,
#  17,
#  17,
#  14,
#  19,
#  1,
#  17,
#  14,
#  1,
#  1,
#  17,
#  7,
#  17,
#  17,
#  17,
#  1,
#  17,
#  1,
#  17,
#  19,
#  4,
#  19,
#  1,
#  17,
#  17,
#  17,
#  7,
#  17,
#  1,
#  17,
#  4,
#  14,
#  4,
#  19,
#  1,
#  17,
#  14,
#  17,
#  17,
#  19,
#  1,
#  17,
#  14,
#  1,
#  17,
#  17,
#  14,
#  17,
#  17,
#  7,
#  17,
#  19,
#  17,
#  14,
#  1,
#  1,
#  17,
#  7,
#  1,
#  17,
#  17,
#  17,
#  7,
#  17,
#  17,
#  14,
#  1,
#  1,
#  17,
#  1,
#  7,
#  1,
#  17,
#  17,
#  1,
#  17,
#  14,
#  17,
#  17,
#  17,
#  17,
#  14,
#  17,
#  1,
#  17,
#  ...]

# %%
import numpy as np

Y_ts = np.asarray(Y_ts)
Y_ts
# Out:
# array([17,  1, 17, ..., 14, 17, 17])

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(Y_ts, Y_pred))
# Out:
# 0.3179255918827508

# %%
print (classification_report(Y_ts, Y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00       299
#           4       0.00      0.00      0.00       197
#           6       0.00      0.00      0.00         8
#           7       0.00      0.00      0.00       148
#          10       0.00      0.00      0.00         0
#          11       0.01      0.21      0.01        14
#          14       0.00      0.00      0.00       352
#          17       0.42      0.76      0.54      1103
#          19       0.00      0.00      0.00       376
#          20       0.00      0.00      0.00       164
#
# avg / total       0.17      0.32      0.22      2661
# c:\users\maria tsareva\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\maria tsareva\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=200, n_jobs=-1, verbose=5) 
clf = clf.fit(X, y)
# Out:
# building tree 1 of 200building tree 2 of 200
#
# building tree 3 of 200
# building tree 4 of 200

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X.toarray(), y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-49c687b27bf5> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 clf = GaussianNB()
# ----> 3 clf.fit(X.toarray(), y)
#
# c:\users\maria tsareva\appdata\local\programs\python\python36-32\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#     941         if out is None and order is None:
#     942             order = self._swap('cf')[0]
# --> 943         out = self._process_toarray_args(order, out)
#     944         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     945             raise ValueError('Output array must be C or F contiguous')
#
# c:\users\maria tsareva\appdata\local\programs\python\python36-32\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1128             return out
#    1129         else:
# -> 1130             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1131
#    1132     def __numpy_ufunc__(self, func, method, pos, inputs, **kwargs):
#
# ValueError: array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.
